# %%
import pandas as pd

# Asegúrate de poner el nombre del archivo entre comillas
df = pd.read_csv("Tabla dinámica Especialistas.csv", encoding='latin-1')

# Ahora puedes trabajar con el DataFrame df

df
# Out:
#                Cantidad de Cardiólogos;
# 0                        Regiones;Total
# 1                  Arica y Parinacota;3
# 2                            Tarapacá;6
# 3                        Antofagasta;10
# 4                             Atacama;6
# 5                           Coquimbo;24
# 6                         Valparaíso;62
# 7                     Metropolitana;233
# 8      Libertador Bernardo O'Higgins;11
# 9                              Maule;73
# 10                             Ñuble;10
# 11                           Bío Bío;63
# 12                         Araucanía;30
# 13                          Los Ríos;11
# 14                         Los Lagos;24
# 15                              Aysén;1
# 16  Magallanes y la Antártica Chilena;2
# 17                       Total país;569
# 18                                    ;
# 19               Cantidad de Oncólogos;
# 20                       Regiones;Total
# 21                 Arica y Parinacota;1
# 22                           Tarapacá;3
# 23                        Antofagasta;5
# 24                            Atacama;0
# 25                           Coquimbo;3
# 26                        Valparaíso;20
# 27                     Metropolitana;81
# 28      Libertador Bernardo O'Higgins;4
# 29                              Maule;9
# 30                              Ñuble;0
# 31                           Bío Bío;11
# 32                         Araucanía;10
# 33                           Los Ríos;4
# 34                          Los Lagos;3
# 35                              Aysén;0
# 36  Magallanes y la Antártica Chilena;1
# 37                       Total país;155
